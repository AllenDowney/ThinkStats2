# %%
"""This file contains code used in "Think Stats",
by Allen B. Downey, available from greenteapress.com

Copyright 2010 Allen B. Downey
License: GNU GPLv3 http://www.gnu.org/licenses/gpl.html
"""

from __future__ import print_function, division

import math
import pandas
import patsy
import random
import numpy as np
import statsmodels.api as sm
import statsmodels.formula.api as smf
import re

import chap01soln
import first
import linear
import thinkplot
import thinkstats2

# %%
thinkstats2.RandomSeed(17)

# %% [markdown]
# - see the file `first.py`
# - read input file and returns three dataframes

# %%
live, firsts, others = first.MakeFrames()
live['isfirst'] = (live.birthord == 1)
live.head()
# Out:
#    caseid  pregordr  howpreg_n  howpreg_p  moscurrp  nowprgdk  pregend1  \
# 0       1         1        NaN        NaN       NaN       NaN       6.0
# 1       1         2        NaN        NaN       NaN       NaN       6.0
# 2       2         1        NaN        NaN       NaN       NaN       5.0
# 3       2         2        NaN        NaN       NaN       NaN       6.0
# 4       2         3        NaN        NaN       NaN       NaN       6.0
#
#    pregend2  nbrnaliv  multbrth   ...     religion_i  metro_i      basewgt  \
# 0       NaN       1.0       NaN   ...              0        0  3410.389399
# 1       NaN       1.0       NaN   ...              0        0  3410.389399
# 2       NaN       3.0       5.0   ...              0        0  7226.301740
# 3       NaN       1.0       NaN   ...              0        0  7226.301740
# 4       NaN       1.0       NaN   ...              0        0  7226.301740
#
#    adj_mod_basewgt      finalwgt  secu_p  sest  cmintvw  totalwgt_lb  isfirst
# 0      3869.349602   6448.271112       2     9      NaN       8.8125     True
# 1      3869.349602   6448.271112       2     9      NaN       7.8750    False
# 2      8567.549110  12999.542264       2    12      NaN       9.1250     True
# 3      8567.549110  12999.542264       2    12      NaN       7.0000    False
# 4      8567.549110  12999.542264       2    12      NaN       6.1875    False
#
# [5 rows x 245 columns]

# %%
def RunSimpleRegression(live):
    """Runs a simple regression and compare results to thinkstats2 functions.

    live: DataFrame of live births
    """
    # run the regression with thinkstats2 functions
    live_dropna = live.dropna(subset=['agepreg', 'totalwgt_lb'])
    ages = live_dropna.agepreg
    weights = live_dropna.totalwgt_lb
    inter, slope = thinkstats2.LeastSquares(ages, weights)
    res = thinkstats2.Residuals(ages, weights, inter, slope)
    r2 = thinkstats2.CoefDetermination(weights, res)

    # run the regression with statsmodels
    formula = 'totalwgt_lb ~ agepreg'
    model = smf.ols(formula, data=live)
    results = model.fit()
    
    SummarizeResults(results)

    def AlmostEquals(x, y, tol=1e-6):
        return abs(x-y) < tol

    assert(AlmostEquals(results.params['Intercept'], inter))
    assert(AlmostEquals(results.params['agepreg'], slope))
    assert(AlmostEquals(results.rsquared, r2))
#

# %%
def SummarizeResults(results):
    """Prints the most important parts of linear regression results:

    results: RegressionResults object
    """
    for name, param in results.params.items():
        pvalue = results.pvalues[name]
        print('%s   %0.3g   (%.3g)' % (name, param, pvalue))

    try:
        print('R^2 %.4g' % results.rsquared)
        ys = results.model.endog
        print('Std(ys) %.4g' % ys.std())
        print('Std(res) %.4g' % results.resid.std())
    except AttributeError:
        print('R^2 %.4g' % results.prsquared)
        
    print (' ----- ')

# %%
RunSimpleRegression(live)
# Out:
# Intercept   6.83   (0)
# agepreg   0.0175   (5.72e-11)
# R^2 0.004738
# Std(ys) 1.408
# Std(res) 1.405
#  -----

# %%
def FormatRow(results, columns):
    """Converts regression results to a string.

    results: RegressionResults object

    returns: string
    """
    t = []
    for col in columns:
        coef = results.params.get(col, np.nan)
        pval = results.pvalues.get(col, np.nan)
        if np.isnan(coef):
            s = '--'
        elif pval < 0.001:
            s = '%0.3g (*)' % (coef)
        else:
            s = '%0.3g (%0.2g)' % (coef, pval)
        t.append(s)

    try:
        t.append('%.2g' % results.rsquared)
    except AttributeError:
        t.append('%.2g' % results.prsquared)
        
    return t

# %%
def RunModels(live):
    """Runs regressions that predict birth weight.

    live: DataFrame of pregnancy records
    """
    columns = ['isfirst[T.True]', 'agepreg', 'agepreg2']
    header = ['isfirst', 'agepreg', 'agepreg2']

    rows = []
    formula = 'totalwgt_lb ~ isfirst'
    results = smf.ols(formula, data=live).fit()
    rows.append(FormatRow(results, columns))
    print(formula)
    SummarizeResults(results)
    #
    formula = 'totalwgt_lb ~ agepreg'
    results = smf.ols(formula, data=live).fit()
    rows.append(FormatRow(results, columns))
    print(formula)
    SummarizeResults(results)
    
    formula = 'totalwgt_lb ~ isfirst + agepreg'
    results = smf.ols(formula, data=live).fit()
    rows.append(FormatRow(results, columns))
    print(formula)
    SummarizeResults(results)
    
    live['agepreg2'] = live.agepreg**2
    formula = 'totalwgt_lb ~ isfirst + agepreg + agepreg2'
    results = smf.ols(formula, data=live).fit()
    rows.append(FormatRow(results, columns))
    print(formula)
    SummarizeResults(results)
    
    # PrintTabular(rows, header)  # Don't have to have this
#

# %%
RunModels (live)
# Out:
# totalwgt_lb ~ isfirst
# Intercept   7.33   (0)
# isfirst[T.True]   -0.125   (2.55e-05)
# R^2 0.00196
# Std(ys) 1.408
# Std(res) 1.407
#  -----
# totalwgt_lb ~ agepreg
# Intercept   6.83   (0)
# agepreg   0.0175   (5.72e-11)
# R^2 0.004738
# Std(ys) 1.408
# Std(res) 1.405
#  -----
# totalwgt_lb ~ isfirst + agepreg
# Intercept   6.91   (0)
# isfirst[T.True]   -0.0698   (0.0253)
# agepreg   0.0154   (3.93e-08)
# R^2 0.005289
# Std(ys) 1.408
# Std(res) 1.405
#  -----
# totalwgt_lb ~ isfirst + agepreg + agepreg2
# Intercept   5.69   (1.38e-86)
# isfirst[T.True]   -0.0504   (0.109)
# agepreg   0.112   (3.23e-07)
# agepreg2   -0.00185   (8.8e-06)
# R^2 0.007462
# Std(ys) 1.408
# Std(res) 1.403
#  -----

# %%
def ReadVariables():
    """Reads Stata dictionary files for NSFG data.

    returns: DataFrame that maps variables names to descriptions
    """
    vars1 = thinkstats2.ReadStataDct('2002FemPreg.dct').variables
    vars2 = thinkstats2.ReadStataDct('2002FemResp.dct').variables

    all_vars = vars1.append(vars2)
    all_vars.index = all_vars.name
    return all_vars
#

MESSAGE = """If you get this error, it's probably because 
you are running Python 3 and the nice people who maintain
Patsy have not fixed this problem:
https://github.com/pydata/patsy/issues/34

While we wait, I suggest running this example in
Python 2, or skipping this example."""


def GoMining(df, printFlag=False):
    """Searches for variables that predict birth weight.

    df: DataFrame of pregnancy records

    returns: list of (rsquared, variable name) pairs
    """
    cnt = 1
    variables = []
    for name in df.columns:
        try:
            if df[name].var() < 1e-7:
                continue

            formula = 'totalwgt_lb ~ agepreg + ' + name
#            formula = formula.encode('ascii')

            if printFlag:
                print ('>>>> ({}) model = smf.ols({}, data=df)'.format(cnt, formula))

            model = smf.ols(formula, data=df)
            if model.nobs < len(df)/2:
                continue

            results = model.fit()
            if printFlag:
                print (results.summary())
                print ('>>>> {} --------------- '.format(cnt))
                cnt += 1
            #
        except (ValueError, TypeError):
            continue
        except patsy.PatsyError:
            raise ValueError(MESSAGE)

        variables.append((results.rsquared, name))

    return variables
#

def MiningReport(variables, n=30):
    """Prints variables with the highest R^2.

    t: list of (R^2, variable name) pairs
    n: number of pairs to print
    """
    all_vars = ReadVariables()
    print ('all_vars = [{}]'.format(all_vars))
    
    variables.sort(reverse=True)
    for mse, name in variables[:n]:
        key = re.sub('_r$', '', name)
        try:
            desc = all_vars.loc[key].desc
            print ('@@@ MiningReport: mse = [{}] name = [{}] key = [{}] desc = [{}]'.format(mse, name, key, desc))
            if isinstance(desc, pandas.Series):
                desc = desc[0]
            print(name, mse, desc)
        except KeyError:
            print(name, mse)
#

def JoinFemResp(df):
    """Reads the female respondent file and joins on caseid.

    df: DataFrame
    """
    resp = chap01soln.ReadFemResp()
    resp.index = resp.caseid

    join = df.join(resp, on='caseid', rsuffix='_r')

    # convert from colon-separated time strings to datetimes
    join.screentime = pandas.to_datetime(join.screentime)

    return join

# %%
#def PredictBirthWeight(live):
"""Predicts birth weight of a baby at 30 weeks.

live: DataFrame of live births
"""
live = live[live.prglngth>30]
join = JoinFemResp(live)
join['nbrnaliv'].head()
# Out:
# 0    1.0
# 1    1.0
# 2    3.0
# 3    1.0
# 4    1.0
# Name: nbrnaliv, dtype: float64

# %%
join.head()
# Out:
#    caseid  pregordr  howpreg_n  howpreg_p  moscurrp  nowprgdk  pregend1  \
# 0       1         1        NaN        NaN       NaN       NaN       6.0
# 1       1         2        NaN        NaN       NaN       NaN       6.0
# 2       2         1        NaN        NaN       NaN       NaN       5.0
# 3       2         2        NaN        NaN       NaN       NaN       6.0
# 4       2         3        NaN        NaN       NaN       NaN       6.0
#
#    pregend2  nbrnaliv  multbrth     ...      pubassis_i_r    basewgt_r  \
# 0       NaN       1.0       NaN     ...                 0  3410.389399
# 1       NaN       1.0       NaN     ...                 0  3410.389399
# 2       NaN       3.0       5.0     ...                 0  7226.301740
# 3       NaN       1.0       NaN     ...                 0  7226.301740
# 4       NaN       1.0       NaN     ...                 0  7226.301740
#
#    adj_mod_basewgt_r    finalwgt_r  secu_r  sest_r  cmintvw_r  cmlstyr  \
# 0        3869.349602   6448.271112       2       9       1231     1219
# 1        3869.349602   6448.271112       2       9       1231     1219
# 2        8567.549110  12999.542264       2      12       1231     1219
# 3        8567.549110  12999.542264       2      12       1231     1219
# 4        8567.549110  12999.542264       2      12       1231     1219
#
#            screentime   intvlngth
# 0 2018-06-04 19:56:43   67.563833
# 1 2018-06-04 19:56:43   67.563833
# 2 2018-06-04 14:54:03  106.018167
# 3 2018-06-04 14:54:03  106.018167
# 4 2018-06-04 14:54:03  106.018167
#
# [5 rows x 3333 columns]

# %%
join[join.babysex==1].head()
# Out:
#     caseid  pregordr  howpreg_n  howpreg_p  moscurrp  nowprgdk  pregend1  \
# 0        1         1        NaN        NaN       NaN       NaN       6.0
# 2        2         1        NaN        NaN       NaN       NaN       5.0
# 5        6         1        NaN        NaN       NaN       NaN       6.0
# 8        7         1        NaN        NaN       NaN       NaN       5.0
# 10      12         1        NaN        NaN       NaN       NaN       5.0
#
#     pregend2  nbrnaliv  multbrth     ...      pubassis_i_r    basewgt_r  \
# 0        NaN       1.0       NaN     ...                 0  3410.389399
# 2        NaN       3.0       5.0     ...                 0  7226.301740
# 5        NaN       1.0       NaN     ...                 0  4870.926435
# 8        NaN       1.0       NaN     ...                 0  3409.579565
# 10       NaN       1.0       NaN     ...                 0  3612.781968
#
#     adj_mod_basewgt_r    finalwgt_r  secu_r  sest_r  cmintvw_r  cmlstyr  \
# 0         3869.349602   6448.271112       2       9       1231     1219
# 2         8567.549110  12999.542264       2      12       1231     1219
# 5         5325.196999   8874.440799       1      23       1231     1219
# 8         3787.539000   6911.879921       2      14       1233     1221
# 10        4146.013572   6909.331618       1      31       1231     1219
#
#             screentime   intvlngth
# 0  2018-06-04 19:56:43   67.563833
# 2  2018-06-04 14:54:03  106.018167
# 5  2018-06-04 16:29:28  117.349167
# 8  2018-06-04 12:48:37  118.330667
# 10 2018-06-04 18:04:45   85.785500
#
# [5 rows x 3333 columns]

# %%
# def PredictBirthWeight(live):
t = GoMining(join, printFlag=False)
MiningReport(t)
# Out:
# all_vars = [                 start             type             name fstring  \
# name
# caseid               1    <class 'str'>           caseid    %12s
# pregordr            13    <class 'int'>         pregordr     %2f
# howpreg_n           15    <class 'int'>        howpreg_n     %2f
# howpreg_p           17    <class 'int'>        howpreg_p     %1f
# moscurrp            18    <class 'int'>         moscurrp     %1f
# nowprgdk            19    <class 'int'>         nowprgdk     %1f
# pregend1            20    <class 'int'>         pregend1     %1f
# pregend2            21    <class 'int'>         pregend2     %1f
# nbrnaliv            22    <class 'int'>         nbrnaliv     %1f
# multbrth            23    <class 'int'>         multbrth     %1f
# cmotpreg            24    <class 'int'>         cmotpreg     %4f
# prgoutcome          28    <class 'int'>       prgoutcome     %1f
# cmprgend            29    <class 'int'>         cmprgend     %4f
# flgdkmo1            33    <class 'int'>         flgdkmo1     %1f
# cmprgbeg            34    <class 'int'>         cmprgbeg     %4f
# ageatend            38    <class 'int'>         ageatend     %2f
# hpageend            40    <class 'int'>         hpageend     %2f
# gestasun_m          42    <class 'int'>       gestasun_m     %2f
# gestasun_w          44    <class 'int'>       gestasun_w     %2f
# wksgest             46    <class 'int'>          wksgest     %2f
# mosgest             48    <class 'int'>          mosgest     %2f
# dk1gest             50    <class 'int'>          dk1gest     %1f
# dk2gest             51    <class 'int'>          dk2gest     %1f
# dk3gest             52    <class 'int'>          dk3gest     %1f
# bpa_bdscheck1       53    <class 'int'>    bpa_bdscheck1     %1f
# bpa_bdscheck2       54    <class 'int'>    bpa_bdscheck2     %1f
# bpa_bdscheck3       55    <class 'int'>    bpa_bdscheck3     %1f
# babysex             56    <class 'int'>          babysex     %1f
# birthwgt_lb         57    <class 'int'>      birthwgt_lb     %2f
# birthwgt_oz         59    <class 'int'>      birthwgt_oz     %2f
# ...                ...              ...              ...     ...
# advice_i          4813    <class 'int'>         advice_i     %1f
# insem_i           4814    <class 'int'>          insem_i     %1f
# invitro_i         4815    <class 'int'>        invitro_i     %1f
# endomet_i         4816    <class 'int'>        endomet_i     %1f
# fibroids_i        4817    <class 'int'>       fibroids_i     %1f
# pidtreat_i        4818    <class 'int'>       pidtreat_i     %1f
# evhivtst_i        4819    <class 'int'>       evhivtst_i     %1f
# insuranc          4820    <class 'int'>         insuranc     %1f
# metro             4821    <class 'int'>            metro     %1f
# religion          4822    <class 'int'>         religion     %1f
# laborfor          4823    <class 'int'>         laborfor     %1f
# insuranc_i        4824    <class 'int'>       insuranc_i     %1f
# metro_i           4825    <class 'int'>          metro_i     %1f
# religion_i        4826    <class 'int'>       religion_i     %1f
# laborfor_i        4827    <class 'int'>       laborfor_i     %1f
# poverty           4828    <class 'int'>          poverty     %3f
# totincr           4831    <class 'int'>          totincr     %2f
# pubassis          4833    <class 'int'>         pubassis     %1f
# poverty_i         4834    <class 'int'>        poverty_i     %1f
# totincr_i         4835    <class 'int'>        totincr_i     %1f
# pubassis_i        4836    <class 'int'>       pubassis_i     %1f
# basewgt           4837  <class 'float'>          basewgt    %18f
# adj_mod_basewgt   4855  <class 'float'>  adj_mod_basewgt    %18f
# finalwgt          4873  <class 'float'>         finalwgt    %18f
# secu_r            4891    <class 'int'>           secu_r     %1f
# sest              4892    <class 'int'>             sest     %2f
# cmintvw           4894    <class 'int'>          cmintvw     %4f
# cmlstyr           4898    <class 'int'>          cmlstyr     %4f
# screentime        4902    <class 'str'>       screentime     %8s
# intvlngth         4910  <class 'float'>        intvlngth    %18f
#
#                                                               desc     end
# name
# caseid                                        RESPONDENT ID NUMBER    13.0
# pregordr                                  PREGNANCY ORDER (NUMBER)    15.0
# howpreg_n             BB-2 # OF WEEKS OR MONTHS CURRENTLY PREGNANT    17.0
# howpreg_p        BB-2 CURRENT PREGNANCY LENGTH REPORTED IN MONT...    18.0
# moscurrp                       NUMBER OF MONTHS CURRENTLY PREGNANT    19.0
# nowprgdk                 BB-3 WHICH TRIMESTER -- CURRENT PREGNANCY    20.0
# pregend1                    BC-1 HOW PREGNANCY ENDED - 1ST MENTION    21.0
# pregend2                    BC-1 HOW PREGNANCY ENDED - 2ND MENTION    22.0
# nbrnaliv         BC-2 NUMBER OF BABIES BORN ALIVE FROM THIS PRE...    23.0
# multbrth                            BC-3 WAS THIS A MULTIPLE BIRTH    24.0
# cmotpreg               CM FOR PREGNANCY END DATE (IF NONLIVEBIRTH)    28.0
# prgoutcome       OUTCOME OF PREGNANCY (BASED ON PRIORITY ORDERING)    29.0
# cmprgend         CM FOR PREGNANCY END DATE (REGARDLESS OF OUTCOME)    33.0
# flgdkmo1         FLAG INDICATING SEASON/DK/RF FOR BC-4A DATPRGEN_M    34.0
# cmprgbeg                               CM FOR PREGNANCY START DATE    38.0
# ageatend                     BC-4B R'S AGE AT PREGNANCY'S END DATE    40.0
# hpageend                BC-4C FATHER'S AGE AT PREGNANCY'S END DATE    42.0
# gestasun_m          BC-5 GESTATIONAL LENGTH OF PREGNANCY IN MONTHS    44.0
# gestasun_w           BC-5 GESTATIONAL LENGTH OF PREGNANCY IN WEEKS    46.0
# wksgest          GESTATIONAL LENGTH OF COMPLETED PREGNANCY (IN ...    48.0
# mosgest          GESTATIONAL LENGTH OF COMPLETED PREGNANCY (IN ...    50.0
# dk1gest          BC-6 DK FOLLOWUP FOR GESTATIONAL LENGTH OF A S...    51.0
# dk2gest          BC-7 DK FOLLOWUP FOR GESTATIONAL LENGTH OF A L...    52.0
# dk3gest          BC-8 DK FOLLOWUP FOR GESTATIONAL LENGTH OF A M...    53.0
# bpa_bdscheck1    WHETHER 1ST LIVEBORN BABY FROM THIS PREGNANCY ...    54.0
# bpa_bdscheck2    WHETHER 2ND LIVEBORN BABY FROM THIS PREGNANCY ...    55.0
# bpa_bdscheck3    WHETHER 3RD LIVEBORN BABY FROM THIS PREGNANCY ...    56.0
# babysex          BD-2 SEX OF 1ST LIVEBORN BABY FROM THIS PREGNANCY    57.0
# birthwgt_lb      BD-3 BIRTHWEIGHT IN POUNDS - 1ST BABY FROM THI...    59.0
# birthwgt_oz      BD-3 BIRTHWEIGHT IN OUNCES - 1ST BABY FROM THI...    61.0
# ...                                                            ...     ...
# advice_i                                    ADVICE IMPUTATION FLAG  4814.0
# insem_i                                      INSEM IMPUTATION FLAG  4815.0
# invitro_i                                  INVITRO IMPUTATION FLAG  4816.0
# endomet_i                                  ENDOMET IMPUTATION FLAG  4817.0
# fibroids_i                                FIBROIDS IMPUTATION FLAG  4818.0
# pidtreat_i                                PIDTREAT IMPUTATION FLAG  4819.0
# evhivtst_i                                EVHIVTST IMPUTATION FLAG  4820.0
# insuranc                          HEALTH INSURANCE COVERAGE STATUS  4821.0
# metro            PLACE OF RESIDENCE (METROPOLITAN-NON-METROPOLI...  4822.0
# religion                             CURRENT RELIGIOUS AFFILIATION  4823.0
# laborfor                                        LABOR FORCE STATUS  4824.0
# insuranc_i                                INSURANC IMPUTATION FLAG  4825.0
# metro_i                                      METRO IMPUTATION FLAG  4826.0
# religion_i                                RELIGION IMPUTATION FLAG  4827.0
# laborfor_i                                LABORFOR IMPUTATION FLAG  4828.0
# poverty                                       POVERTY LEVEL INCOME  4831.0
# totincr                                 TOTAL INCOME OF R'S FAMILY  4833.0
# pubassis              WHETHER R RECEIVED PUBLIC ASSISTANCE IN 2001  4834.0
# poverty_i                                  POVERTY IMPUTATION FLAG  4835.0
# totincr_i                                  TOTINCR IMPUTATION FLAG  4836.0
# pubassis_i                                PUBASSIS IMPUTATION FLAG  4837.0
# basewgt                                                BASE WEIGHT  4855.0
# adj_mod_basewgt                      ADJUSTED MODIFIED BASE WEIGHT  4873.0
# finalwgt                 FINAL POST-STRATIFIED AND ADJUSTED WEIGHT  4891.0
# secu_r           SCRAMBLED VERSION OF THE SAMPLING ERROR COMPUT...  4892.0
# sest                              SCRAMBLED VERSION OF THE STRATUM  4894.0
# cmintvw                            CENTURY MONTH OF INTERVIEW DATE  4898.0
# cmlstyr           CENTURY MONTH OF MONTH OF INTERVIEW MINUS 1 YEAR  4902.0
# screentime                                        TIME OF SCREENER  4910.0
# intvlngth                              INTERVIEW LENGTH IN MINUTES     0.0
#
# [3330 rows x 6 columns]]
# totalwgt_lb 1.0
# @@@ MiningReport: mse = [0.9498127305978009] name = [birthwgt_lb] key = [birthwgt_lb] desc = [BD-3 BIRTHWEIGHT IN POUNDS - 1ST BABY FROM THIS PREGNANCY]
# birthwgt_lb 0.949812730598 BD-3 BIRTHWEIGHT IN POUNDS - 1ST BABY FROM THIS PREGNANCY
# @@@ MiningReport: mse = [0.30082407844707704] name = [lbw1] key = [lbw1] desc = [LOW BIRTHWEIGHT - BABY 1]
# lbw1 0.300824078447 LOW BIRTHWEIGHT - BABY 1
# @@@ MiningReport: mse = [0.13012519488625052] name = [prglngth] key = [prglngth] desc = [DURATION OF COMPLETED PREGNANCY IN WEEKS]
# prglngth 0.130125194886 DURATION OF COMPLETED PREGNANCY IN WEEKS
# @@@ MiningReport: mse = [0.12340041363361054] name = [wksgest] key = [wksgest] desc = [GESTATIONAL LENGTH OF COMPLETED PREGNANCY (IN WEEKS)]
# wksgest 0.123400413634 GESTATIONAL LENGTH OF COMPLETED PREGNANCY (IN WEEKS)
# @@@ MiningReport: mse = [0.10203149928155986] name = [agecon] key = [agecon] desc = [AGE AT TIME OF CONCEPTION]
# agecon 0.102031499282 AGE AT TIME OF CONCEPTION
# @@@ MiningReport: mse = [0.027144274639579802] name = [mosgest] key = [mosgest] desc = [GESTATIONAL LENGTH OF COMPLETED PREGNANCY (IN MONTHS)]
# mosgest 0.0271442746396 GESTATIONAL LENGTH OF COMPLETED PREGNANCY (IN MONTHS)
# @@@ MiningReport: mse = [0.01855092529394209] name = [babysex] key = [babysex] desc = [BD-2 SEX OF 1ST LIVEBORN BABY FROM THIS PREGNANCY]
# babysex 0.0185509252939 BD-2 SEX OF 1ST LIVEBORN BABY FROM THIS PREGNANCY
# @@@ MiningReport: mse = [0.016199503586253217] name = [race_r] key = [race] desc = [name
# race                  RACE
# race    RACE OF RESPONDENT
# Name: desc, dtype: object]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/anaconda/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_value(self, series, key)
#    2427             return self._engine.get_value(s, k,
# -> 2428                                           tz=getattr(series.dtype, 'tz', None))
#    2429         except KeyError as e1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_value (pandas/_libs/index.c:4363)()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_value (pandas/_libs/index.c:4046)()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc (pandas/_libs/index.c:5022)()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine._get_loc_duplicates (pandas/_libs/index.c:5321)()
#
# TypeError: '>' not supported between instances of 'str' and 'int'
#
# During handling of the above exception, another exception occurred:
#
# IndexError                                Traceback (most recent call last)
# <ipython-input-26-ec96f0b66e37> in <module>()
#       1 # def PredictBirthWeight(live):
#       2 t = GoMining(join, printFlag=False)
# ----> 3 MiningReport(t)
#
# <ipython-input-25-0631bac4473e> in MiningReport(variables, n)
#      77             print ('@@@ MiningReport: mse = [{}] name = [{}] key = [{}] desc = [{}]'.format(mse, name, key, desc))
#      78             if isinstance(desc, pandas.Series):
# ---> 79                 desc = desc[0]
#      80             print(name, mse, desc)
#      81         except KeyError:
#
# ~/anaconda/lib/python3.6/site-packages/pandas/core/series.py in __getitem__(self, key)
#     599         key = com._apply_if_callable(key, self)
#     600         try:
# --> 601             result = self.index.get_value(self, key)
#     602
#     603             if not is_scalar(result):
#
# ~/anaconda/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_value(self, series, key)
#    2446             # python 3
#    2447             if is_scalar(key):  # pragma: no cover
# -> 2448                 raise IndexError(key)
#    2449             raise InvalidIndexError(key)
#    2450
#
# IndexError: 0
